# %% [markdown]
# <a align="left" href="https://ultralytics.com/yolov5" target="_blank">
# <img width="1024", src="https://user-images.githubusercontent.com/26833433/125273437-35b3fc00-e30d-11eb-9079-46f313325424.png"></a>
#
# This is the **official YOLOv5 🚀 notebook** by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-154-gf3ee596 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
# !unzip -q ../Before_Aug.zip -d ../

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
python export.py --weights runs/train/exp/weights/last.pt --include onnx
# Out:
#   File "<ipython-input-4-3985037551cc>", line 1
#     python export.py --weights runs/train/exp/weights/last.pt --include onnx
#                 ^
# SyntaxError: invalid syntax

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source ../video1.mp4
# Out:
# detect: weights=['runs/train/exp3/weights/last.pt'], source=../video1.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-292-g0414637 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.020s)
# video 1/1 (2/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (3/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (4/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (5/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (6/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (7/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (8/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (9/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (10/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (11/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (12/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (13/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (14/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (15/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (16/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (17/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (18/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (19/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (20/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (21/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (22/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (23/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (24/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (25/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (26/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (27/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (28/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (29/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.015s)
# video 1/1 (30/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (31/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (32/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (33/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.015s)
# video 1/1 (34/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (35/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (36/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (37/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (38/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.016s)
# video 1/1 (39/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (40/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.015s)
# video 1/1 (41/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (42/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (43/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (44/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.013s)
# video 1/1 (45/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (46/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (47/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (48/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (49/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (50/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (51/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (52/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (53/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (54/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (55/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (56/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (57/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (58/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (59/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (60/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (61/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (62/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (63/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (64/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (65/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (66/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (67/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (68/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (69/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (70/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (71/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (72/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (73/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (74/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (75/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (76/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (77/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (78/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (79/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (80/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.016s)
# video 1/1 (81/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (82/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (83/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (84/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (85/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (86/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (87/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (88/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (89/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (90/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (91/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (92/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (93/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (94/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (95/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (96/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (97/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (98/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (99/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (100/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (101/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (102/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (103/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (104/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (105/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (106/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (107/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (108/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (109/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (110/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (111/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (112/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (113/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (114/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (115/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (116/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (117/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (118/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (119/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (120/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (121/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (122/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (123/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (124/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (125/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (126/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (127/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (128/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (129/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (130/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (131/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (132/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (133/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (134/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (135/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (136/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.016s)
# video 1/1 (137/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (138/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (139/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (140/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (141/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (142/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (143/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (144/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (145/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (146/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (147/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (148/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (149/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (150/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (151/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (152/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (153/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (154/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (155/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (156/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (157/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (158/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (159/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (160/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.015s)
# video 1/1 (161/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (162/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (163/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.015s)
# video 1/1 (164/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (165/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (166/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (167/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (168/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (169/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (170/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (171/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (172/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.015s)
# video 1/1 (173/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (174/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (175/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (176/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (177/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (178/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (179/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (180/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (181/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (182/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (183/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (184/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (185/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (186/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (187/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (188/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (189/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (190/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (191/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (192/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (193/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (194/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (195/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (196/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (197/958) /content/video1.mp4: 384x640 Done. (0.014s)
# video 1/1 (198/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (199/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (200/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (201/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (202/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (203/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (204/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (205/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (206/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.015s)
# video 1/1 (207/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (208/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (209/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (210/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (211/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (212/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (213/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (214/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (215/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (216/958) /content/video1.mp4: 384x640 Done. (0.010s)
# video 1/1 (217/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (218/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (219/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (220/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (221/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (222/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (223/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (224/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (225/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (226/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (227/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (228/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (229/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (230/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (231/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (232/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (233/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (234/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (235/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (236/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (237/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (238/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (239/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (240/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (241/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (242/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (243/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (244/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (245/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (246/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (247/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (248/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (249/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (250/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (251/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (252/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (253/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (254/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (255/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (256/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (257/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (258/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (259/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (260/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (261/958) /content/video1.mp4: 384x640 Done. (0.014s)
# video 1/1 (262/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (263/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (264/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (265/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (266/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (267/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (268/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (269/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (270/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (271/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (272/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (273/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.015s)
# video 1/1 (274/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (275/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (276/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (277/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (278/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (279/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (280/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (281/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (282/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (283/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (284/958) /content/video1.mp4: 384x640 3 irobots, Done. (0.012s)
# video 1/1 (285/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (286/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (287/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.015s)
# video 1/1 (288/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (289/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.013s)
# video 1/1 (290/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (291/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (292/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.016s)
# video 1/1 (293/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (294/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (295/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (296/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (297/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (298/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (299/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.015s)
# video 1/1 (300/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (301/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (302/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (303/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (304/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (305/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (306/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (307/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (308/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (309/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (310/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (311/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (312/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (313/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (314/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.015s)
# video 1/1 (315/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (316/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (317/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (318/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (319/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (320/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (321/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (322/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (323/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (324/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (325/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.015s)
# video 1/1 (326/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (327/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.016s)
# video 1/1 (328/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (329/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (330/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (331/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (332/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.014s)
# video 1/1 (333/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (334/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (335/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (336/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (337/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (338/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (339/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (340/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (341/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (342/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (343/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.014s)
# video 1/1 (344/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (345/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (346/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (347/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (348/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (349/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (350/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (351/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (352/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (353/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (354/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (355/958) /content/video1.mp4: 384x640 Done. (0.014s)
# video 1/1 (356/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (357/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (358/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (359/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (360/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (361/958) /content/video1.mp4: 384x640 Done. (0.010s)
# video 1/1 (362/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (363/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (364/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (365/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (366/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (367/958) /content/video1.mp4: 384x640 Done. (0.017s)
# video 1/1 (368/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (369/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (370/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (371/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (372/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (373/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (374/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (375/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (376/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (377/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (378/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (379/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (380/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (381/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (382/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (383/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (384/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (385/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (386/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (387/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (388/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (389/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (390/958) /content/video1.mp4: 384x640 Done. (0.010s)
# video 1/1 (391/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (392/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (393/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (394/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (395/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (396/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (397/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (398/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (399/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (400/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (401/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (402/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (403/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (404/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (405/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (406/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (407/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (408/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (409/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (410/958) /content/video1.mp4: 384x640 Done. (0.015s)
# video 1/1 (411/958) /content/video1.mp4: 384x640 Done. (0.015s)
# video 1/1 (412/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (413/958) /content/video1.mp4: 384x640 Done. (0.015s)
# video 1/1 (414/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (415/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (416/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (417/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (418/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (419/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (420/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (421/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (422/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (423/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (424/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (425/958) /content/video1.mp4: 384x640 Done. (0.014s)
# video 1/1 (426/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (427/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (428/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (429/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (430/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (431/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (432/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (433/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (434/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (435/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (436/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (437/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (438/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (439/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (440/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (441/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (442/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (443/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (444/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (445/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (446/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.015s)
# video 1/1 (447/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (448/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (449/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (450/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (451/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (452/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (453/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.016s)
# video 1/1 (454/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (455/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (456/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (457/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (458/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (459/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (460/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (461/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (462/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (463/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (464/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (465/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (466/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (467/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (468/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.013s)
# video 1/1 (469/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (470/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (471/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (472/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (473/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (474/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (475/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (476/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.015s)
# video 1/1 (477/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.013s)
# video 1/1 (478/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (479/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (480/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (481/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (482/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.013s)
# video 1/1 (483/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (484/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (485/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (486/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (487/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.017s)
# video 1/1 (488/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (489/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (490/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (491/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (492/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (493/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (494/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (495/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (496/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (497/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (498/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (499/958) /content/video1.mp4: 384x640 Done. (0.015s)
# video 1/1 (500/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (501/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (502/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (503/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (504/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (505/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (506/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (507/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (508/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (509/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (510/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (511/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (512/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (513/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (514/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (515/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (516/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (517/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (518/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (519/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (520/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (521/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (522/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (523/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (524/958) /content/video1.mp4: 384x640 Done. (0.014s)
# video 1/1 (525/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (526/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (527/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (528/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (529/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (530/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (531/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (532/958) /content/video1.mp4: 384x640 Done. (0.014s)
# video 1/1 (533/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (534/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (535/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.015s)
# video 1/1 (536/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (537/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (538/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (539/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (540/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (541/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (542/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.017s)
# video 1/1 (543/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (544/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (545/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (546/958) /content/video1.mp4: 384x640 Done. (0.015s)
# video 1/1 (547/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (548/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (549/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (550/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (551/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (552/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (553/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (554/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.015s)
# video 1/1 (555/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (556/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (557/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (558/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (559/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (560/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (561/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (562/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (563/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (564/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (565/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (566/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.015s)
# video 1/1 (567/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (568/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (569/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (570/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.017s)
# video 1/1 (571/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (572/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (573/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (574/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (575/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (576/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (577/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (578/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (579/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (580/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (581/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (582/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (583/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (584/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (585/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (586/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (587/958) /content/video1.mp4: 384x640 Done. (0.014s)
# video 1/1 (588/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (589/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (590/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (591/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (592/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (593/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (594/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (595/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (596/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (597/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (598/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (599/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (600/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (601/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.016s)
# video 1/1 (602/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (603/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (604/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (605/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (606/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (607/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (608/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (609/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (610/958) /content/video1.mp4: 384x640 Done. (0.017s)
# video 1/1 (611/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (612/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (613/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (614/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (615/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (616/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (617/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (618/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (619/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (620/958) /content/video1.mp4: 384x640 Done. (0.013s)
# video 1/1 (621/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (622/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (623/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (624/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.015s)
# video 1/1 (625/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (626/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (627/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (628/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (629/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (630/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (631/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (632/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (633/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (634/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (635/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (636/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (637/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (638/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (639/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (640/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (641/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (642/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (643/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (644/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (645/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (646/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (647/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (648/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.013s)
# video 1/1 (649/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (650/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (651/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (652/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (653/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (654/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (655/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (656/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (657/958) /content/video1.mp4: 384x640 Done. (0.012s)
# video 1/1 (658/958) /content/video1.mp4: 384x640 Done. (0.015s)
# video 1/1 (659/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (660/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (661/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (662/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (663/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (664/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (665/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (666/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (667/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (668/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (669/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (670/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (671/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (672/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (673/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# ...
# video 1/1 (745/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (746/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (747/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (748/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (749/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (750/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (751/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (752/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (753/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (754/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (755/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (756/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (757/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (758/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (759/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (760/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (761/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (762/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (763/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (764/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (765/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.015s)
# video 1/1 (766/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (767/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (768/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (769/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (770/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.015s)
# video 1/1 (771/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (772/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (773/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (774/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (775/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (776/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (777/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (778/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (779/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (780/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (781/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (782/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (783/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (784/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (785/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (786/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (787/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (788/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (789/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (790/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (791/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (792/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (793/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (794/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (795/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (796/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (797/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (798/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (799/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (800/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (801/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (802/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (803/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (804/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (805/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (806/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.016s)
# video 1/1 (807/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (808/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (809/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (810/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (811/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (812/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (813/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (814/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (815/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (816/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (817/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (818/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.016s)
# video 1/1 (819/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (820/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (821/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (822/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (823/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (824/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (825/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (826/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (827/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (828/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (829/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (830/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (831/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (832/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (833/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (834/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (835/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (836/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (837/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (838/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (839/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (840/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (841/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (842/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (843/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (844/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (845/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (846/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (847/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (848/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (849/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (850/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (851/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (852/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (853/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (854/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (855/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (856/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (857/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (858/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.015s)
# video 1/1 (859/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (860/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (861/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (862/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (863/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (864/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (865/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (866/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (867/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (868/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (869/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (870/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (871/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (872/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (873/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (874/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (875/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (876/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (877/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (878/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (879/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (880/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (881/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (882/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (883/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (884/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (885/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (886/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (887/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (888/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (889/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.012s)
# video 1/1 (890/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.014s)
# video 1/1 (891/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (892/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (893/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (894/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (895/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (896/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (897/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (898/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (899/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (900/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (901/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (902/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (903/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (904/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (905/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (906/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (907/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (908/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.013s)
# video 1/1 (909/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (910/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (911/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (912/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (913/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (914/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (915/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.011s)
# video 1/1 (916/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (917/958) /content/video1.mp4: 384x640 Done. (0.011s)
# video 1/1 (918/958) /content/video1.mp4: 384x640 1 irobot, Done. (0.010s)
# video 1/1 (919/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (920/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (921/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (922/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (923/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.010s)
# video 1/1 (924/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.010s)
# video 1/1 (925/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (926/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.010s)
# video 1/1 (927/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (928/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (929/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (930/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.010s)
# video 1/1 (931/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (932/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (933/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.010s)
# video 1/1 (934/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.010s)
# video 1/1 (935/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (936/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.014s)
# video 1/1 (937/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.014s)
# video 1/1 (938/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.010s)
# video 1/1 (939/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.010s)
# video 1/1 (940/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (941/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (942/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.010s)
# video 1/1 (943/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (944/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.010s)
# video 1/1 (945/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (946/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (947/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (948/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (949/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (950/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.012s)
# video 1/1 (951/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.013s)
# video 1/1 (952/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (953/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (954/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (955/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (956/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.011s)
# video 1/1 (957/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.010s)
# video 1/1 (958/958) /content/video1.mp4: 384x640 2 irobots, Done. (0.010s)
# Speed: 0.5ms pre-process, 11.7ms inference, 0.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on [COCO](https://cocodataset.org/#home) val or test-dev datasets. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be ~1% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %% [markdown]
# ## COCO val
# Download [COCO val 2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L14) dataset (1GB - 5000 images), and test model accuracy.

# %%
# Download COCO val
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# Out:
#   0%|          | 0.00/780M [00:00<?, ?B/s]

# %%
# Run YOLOv5x on COCO val
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5x.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v6.1-257-g669f707 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla V100-SXM2-16GB, 16160MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5x.pt to yolov5x.pt...
# 100% 166M/166M [00:04<00:00, 39.4MB/s]
#
# Fusing layers...
# YOLOv5x summary: 444 layers, 86705005 parameters, 0 gradients
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 47.9MB/s]
# val: Scanning '/content/datasets/coco/val2017' images and labels...4952 found, 48 missing, 0 empty, 0 corrupt: 100% 5000/5000 [00:00<00:00, 8742.34it/s]
# val: New cache created: /content/datasets/coco/val2017.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 157/157 [01:11<00:00,  2.21it/s]
#                  all       5000      36335      0.743      0.625      0.683      0.504
# Speed: 0.1ms pre-process, 4.9ms inference, 1.2ms NMS per image at shape (32, 3, 640, 640)
#
# Evaluating pycocotools mAP... saving runs/val/exp/yolov5x_predictions.json...
# loading annotations into memory...
# Done (t=0.42s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=4.91s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=77.89s).
# Accumulating evaluation results...
# DONE (t=15.36s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.506
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.688
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.549
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.340
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.557
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.651
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.631
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.684
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.528
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.737
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.833
# Results saved to runs/val/exp

# %% [markdown]
# ## COCO test
# Download [COCO test2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L15) dataset (7GB - 40,000 images), to test model accuracy on test-dev set (**20,000 images, no labels**). Results are saved to a `*.json` file which should be **zipped** and submitted to the evaluation server at https://competitions.codalab.org/competitions/20794.

# %%
# Download COCO test-dev2017
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017labels.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# !f="test2017.zip" && curl http://images.cocodataset.org/zips/$f -o $f && unzip -q $f -d ../datasets/coco/images

# %%
# Run YOLOv5x on COCO test
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half --task test

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="1000" src="https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/615627e5824c9c6195abfda9_computer-vision-cycle.png"/></a></p>
# Close the active learning loop by sampling images from your inference conditions with the `roboflow` pip package
# <br><br>
#
# Train a YOLOv5s model on the [COCO128](https://www.kaggle.com/ultralytics/coco128) dataset with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`.
#
# - **Pretrained [Models](https://github.com/ultralytics/yolov5/tree/master/models)** are downloaded
# automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases)
# - **[Datasets](https://github.com/ultralytics/yolov5/tree/master/data)** available for autodownload include: [COCO](https://github.com/ultralytics/yolov5/blob/master/data/coco.yaml), [COCO128](https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml), [VOC](https://github.com/ultralytics/yolov5/blob/master/data/VOC.yaml), [Argoverse](https://github.com/ultralytics/yolov5/blob/master/data/Argoverse.yaml), [VisDrone](https://github.com/ultralytics/yolov5/blob/master/data/VisDrone.yaml), [GlobalWheat](https://github.com/ultralytics/yolov5/blob/master/data/GlobalWheat2020.yaml), [xView](https://github.com/ultralytics/yolov5/blob/master/data/xView.yaml), [Objects365](https://github.com/ultralytics/yolov5/blob/master/data/Objects365.yaml), [SKU-110K](https://github.com/ultralytics/yolov5/blob/master/data/SKU-110K.yaml).
# - **Training Results** are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.
# <br><br>
#
# ## Train on Custom Data with Roboflow 🌟 NEW
#
# [Roboflow](https://roboflow.com/?ref=ultralytics) enables you to easily **organize, label, and prepare** a high quality dataset with your own custom data. Roboflow also makes it easy to establish an active learning pipeline, collaborate with your team on dataset improvement, and integrate directly into your model building workflow with the `roboflow` pip package.
#
# - Custom Training Example: [https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/](https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/?ref=ultralytics)
# - Custom Training Notebook: [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/yolov5-custom-training-tutorial/blob/main/yolov5-custom-training.ipynb)
# <br>
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="480" src="https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/6152a275ad4b4ac20cd2e21a_roboflow-annotate.gif"/></a></p>Label images lightning fast (including with model-assisted labeling)

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 25 --data Custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=Custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=25, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-154-gf3ee596 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/Before_Aug/labels/train.cache... 103 images, 0 backgrounds, 0 corrupt: 100% 103/103 [00:00<?, ?it/s]
# train: Caching images (0.1GB ram): 100% 103/103 [00:02<00:00, 48.50it/s]
# val: Scanning /content/Before_Aug/labels/val.cache... 31 images, 0 backgrounds, 0 corrupt: 100% 31/31 [00:00<?, ?it/s]
# val: Caching images (0.0GB ram): 100% 31/31 [00:00<00:00, 33.44it/s]
#
# AutoAnchor: 3.46 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp4/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp4
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/24      3.46G     0.1265    0.03326          0         14        640: 100% 7/7 [00:05<00:00,  1.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 2.050s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.43s/it]
#                    all         31         41     0.0479       0.22     0.0272    0.00545
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/24      4.24G     0.1082    0.03484          0         26        640: 100% 7/7 [00:01<00:00,  4.56it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.51s/it]
#                    all         31         41     0.0265      0.341      0.021    0.00492
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/24      4.24G    0.08382    0.03247          0         21        640: 100% 7/7 [00:01<00:00,  4.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.19it/s]
#                    all         31         41      0.245      0.244      0.164     0.0642
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/24      4.24G     0.0805    0.03202          0         14        640: 100% 7/7 [00:01<00:00,  4.97it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.68it/s]
#                    all         31         41      0.471      0.488      0.417      0.164
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/24      4.24G      0.069     0.0327          0         23        640: 100% 7/7 [00:01<00:00,  4.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.17it/s]
#                    all         31         41      0.647      0.671      0.637      0.295
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/24      4.24G    0.06566    0.02807          0         30        640: 100% 7/7 [00:01<00:00,  4.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.09it/s]
#                    all         31         41      0.693      0.659      0.667      0.346
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/24      4.24G    0.06175     0.0253          0         15        640: 100% 7/7 [00:01<00:00,  5.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.33it/s]
#                    all         31         41      0.706      0.702      0.764      0.389
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/24      4.24G    0.06066    0.02536          0         22        640: 100% 7/7 [00:01<00:00,  5.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.91it/s]
#                    all         31         41      0.565       0.61      0.663       0.36
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/24      4.24G    0.05534    0.02254          0         24        640: 100% 7/7 [00:01<00:00,  4.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.36it/s]
#                    all         31         41      0.471      0.847      0.661      0.268
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/24      4.24G    0.05522    0.02499          0         12        640: 100% 7/7 [00:01<00:00,  5.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.75it/s]
#                    all         31         41      0.765      0.636        0.8      0.498
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/24      4.24G    0.05154    0.02121          0         17        640: 100% 7/7 [00:01<00:00,  3.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.47it/s]
#                    all         31         41      0.666      0.634      0.694      0.369
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/24      4.24G    0.05163    0.02015          0         19        640: 100% 7/7 [00:01<00:00,  5.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.81it/s]
#                    all         31         41      0.753      0.732      0.814      0.386
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/24      4.24G     0.0546    0.01936          0         20        640: 100% 7/7 [00:01<00:00,  5.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.03it/s]
#                    all         31         41      0.548      0.683      0.664      0.293
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/24      4.24G    0.04903     0.0201          0         22        640: 100% 7/7 [00:01<00:00,  4.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.53it/s]
#                    all         31         41      0.574      0.512       0.59      0.235
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/24      4.24G     0.0449    0.01865          0         15        640: 100% 7/7 [00:01<00:00,  5.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.30it/s]
#                    all         31         41      0.505      0.648      0.658      0.409
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/24      4.24G     0.0472    0.02031          0         31        640: 100% 7/7 [00:01<00:00,  4.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.41it/s]
#                    all         31         41      0.636      0.638      0.715      0.329
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/24      4.24G    0.04421    0.01841          0         25        640: 100% 7/7 [00:01<00:00,  4.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.08it/s]
#                    all         31         41      0.822      0.732      0.845      0.444
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/24      4.24G    0.03748    0.01807          0         22        640: 100% 7/7 [00:01<00:00,  5.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.53it/s]
#                    all         31         41       0.88      0.715      0.851      0.413
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/24      4.24G    0.03809    0.01716          0         15        640: 100% 7/7 [00:01<00:00,  5.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.84it/s]
#                    all         31         41       0.75      0.731      0.811       0.55
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/24      4.24G    0.03731    0.01718          0         25        640: 100% 7/7 [00:01<00:00,  4.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.84it/s]
#                    all         31         41      0.806      0.812      0.873        0.6
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/24      4.24G    0.03788    0.01642          0         23        640: 100% 7/7 [00:01<00:00,  5.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.24it/s]
#                    all         31         41      0.572      0.805      0.777      0.486
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/24      4.24G    0.03558    0.01639          0         31        640: 100% 7/7 [00:01<00:00,  4.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.28it/s]
#                    all         31         41      0.803      0.896      0.886      0.632
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/24      4.24G    0.03041    0.01755          0         25        640: 100% 7/7 [00:01<00:00,  4.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.85it/s]
#                    all         31         41      0.722      0.878      0.849      0.582
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/24      4.24G    0.03043    0.01595          0         21        640: 100% 7/7 [00:01<00:00,  5.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.27it/s]
#                    all         31         41      0.808      0.902       0.89      0.627
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/24      4.24G    0.02893    0.01514          0         19        640: 100% 7/7 [00:01<00:00,  5.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.47it/s]
#                    all         31         41      0.828      0.902      0.903      0.685
#
# 25 epochs completed in 0.019 hours.
# Optimizer stripped from runs/train/exp4/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp4/weights/best.pt, 14.4MB
#
# Validating runs/train/exp4/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.60it/s]
#                    all         31         41      0.828      0.902      0.903      0.685
# Results saved to runs/train/exp4

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Weights & Biases Logging 🌟 NEW
#
# [Weights & Biases](https://wandb.ai/site?utm_campaign=repo_yolo_notebook) (W&B) is now integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home?utm_campaign=repo_yolo_notebook), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <p align="left"><img width="900" alt="Weights & Biases dashboard" src="https://user-images.githubusercontent.com/26833433/135390767-c28b050f-8455-4004-adb0-3b730386e2b2.png"></p>

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and val jpgs to see mosaics, labels, predictions and augmentation effects. Note an Ultralytics **Mosaic Dataloader** is used for training (shown below), which combines 4 images into 1 mosaic during training.
#
# > <img src="https://user-images.githubusercontent.com/26833433/131255960-b536647f-7c61-4f60-bbc5-cb2544d71b2a.jpg" width="700">
# `train_batch0.jpg` shows train batch 0 mosaics and labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/131256748-603cafc7-55d1-4e58-ab26-83657761aed9.jpg" width="700">
# `test_batch0_labels.jpg` shows val batch 0 labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/131256752-3f25d7a5-7b0f-4bb3-ab78-46343c3800fe.jpg" width="700">
# `test_batch0_pred.jpg` shows val batch 0 _predictions_
#
# Training results are automatically logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) as `results.csv`, which is plotted as `results.png` (below) after training completes. You can also plot any `results.csv` file manually:
#
# ```python
# from utils.plots import plot_results
# plot_results('path/to/results.csv')  # plot 'results.csv' as 'results.png'
# ```
#
# <img align="left" width="800" alt="COCO128 Training Results" src="https://user-images.githubusercontent.com/26833433/126906780-8c5e2990-6116-4de6-b78a-367244a33ccf.png">

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab and Kaggle** notebooks with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![CI CPU testing](https://github.com/ultralytics/yolov5/workflows/CI%20CPU%20testing/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on macOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Optional extras below. Unit tests validate repo functionality and should be run on any PRs submitted.

# %%
# Reproduce
for x in 'yolov5n', 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x':
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --task speed  # speed
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.001 --iou 0.65  # mAP

# %%
# PyTorch Hub
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://ultralytics.com/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()

# %%
# CI Checks
# %%shell
export PYTHONPATH="$PWD"  # to run *.py. files in subdirectories
rm -rf runs  # remove runs/
for m in yolov5n; do  # models
  python train.py --img 64 --batch 32 --weights $m.pt --epochs 1 --device 0  # train pretrained
  python train.py --img 64 --batch 32 --weights '' --cfg $m.yaml --epochs 1 --device 0  # train scratch
  for d in 0 cpu; do  # devices
    python val.py --weights $m.pt --device $d # val official
    python val.py --weights runs/train/exp/weights/best.pt --device $d # val custom
    python detect.py --weights $m.pt --device $d  # detect official
    python detect.py --weights runs/train/exp/weights/best.pt --device $d  # detect custom
  done
  python hubconf.py  # hub
  python models/yolo.py --cfg $m.yaml  # build PyTorch model
  python models/tf.py --weights $m.pt  # build TensorFlow model
  python export.py --img 64 --batch 1 --weights $m.pt --include torchscript onnx  # export
done

# %%
# Profile
from utils.torch_utils import profile

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
results = profile(input=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# Evolve
# !python train.py --img 640 --batch 64 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache --noautoanchor --evolve
# !d=runs/train/evolve && cp evolve.* $d && zip -r evolve.zip $d && gsutil mv evolve.zip gs://bucket  # upload results (optional)

# %%
# VOC
for b, m in zip([64, 64, 64, 32, 16], ['yolov5n', 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x']):  # batch, model
  # !python train.py --batch {b} --weights {m}.pt --data VOC.yaml --epochs 50 --img 512 --hyp hyp.VOC.yaml --project VOC --name {m} --cache

# %%
# TensorRT 
# https://docs.nvidia.com/deeplearning/tensorrt/install-guide/index.html#installing-pip
# !pip install -U nvidia-tensorrt --index-url https://pypi.ngc.nvidia.com  # install
# !python export.py --weights yolov5s.pt --include engine --imgsz 640 --device 0  # export
# !python detect.py --weights yolov5s.engine --imgsz 640 --device 0  # inference
# Out:
# Looking in indexes: https://pypi.ngc.nvidia.com, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nvidia-tensorrt
#   Downloading https://developer.download.nvidia.com/compute/redist/nvidia-tensorrt/nvidia_tensorrt-8.4.1.5-cp37-none-linux_x86_64.whl (774.4 MB)
#      |████████████████████████████████| 774.4 MB 17 kB/s
# Collecting nvidia-cublas-cu11
#   Downloading https://developer.download.nvidia.com/compute/redist/nvidia-cublas-cu11/nvidia-cublas-cu11-2022.4.8.tar.gz (16 kB)
# Collecting nvidia-cudnn-cu11
#   Downloading https://developer.download.nvidia.com/compute/redist/nvidia-cudnn-cu11/nvidia-cudnn-cu11-2022.5.19.tar.gz (16 kB)
# Collecting nvidia-cuda-runtime-cu11
#   Downloading https://developer.download.nvidia.com/compute/redist/nvidia-cuda-runtime-cu11/nvidia-cuda-runtime-cu11-2022.4.25.tar.gz (16 kB)
# Collecting nvidia-cublas-cu117
#   Downloading https://developer.download.nvidia.com/compute/redist/nvidia-cublas-cu117/nvidia_cublas_cu117-11.10.1.25-py3-none-manylinux1_x86_64.whl (333.1 MB)
#      |████████████████████████████████| 333.1 MB 37 kB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from nvidia-cublas-cu117->nvidia-cublas-cu11->nvidia-tensorrt) (57.4.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from nvidia-cublas-cu117->nvidia-cublas-cu11->nvidia-tensorrt) (0.37.1)
# Collecting nvidia-cuda-runtime-cu117
#   Downloading https://developer.download.nvidia.com/compute/redist/nvidia-cuda-runtime-cu117/nvidia_cuda_runtime_cu117-11.7.60-py3-none-manylinux1_x86_64.whl (849 kB)
#      |████████████████████████████████| 849 kB 53.7 MB/s
# Collecting nvidia-cudnn-cu116
#   Downloading https://developer.download.nvidia.com/compute/redist/nvidia-cudnn-cu116/nvidia_cudnn_cu116-8.4.0.27-py3-none-manylinux1_x86_64.whl (719.3 MB)
#      |████████████████████████████████| 719.3 MB 16 kB/s
# Building wheels for collected packages: nvidia-cublas-cu11, nvidia-cuda-runtime-cu11, nvidia-cudnn-cu11
#   Building wheel for nvidia-cublas-cu11 (setup.py) ... done
#   Created wheel for nvidia-cublas-cu11: filename=nvidia_cublas_cu11-2022.4.8-py3-none-any.whl size=15624 sha256=1afe69023c5fc19fa70f18ea4b0f4469fee68e1263f9c5ec964ba7dac64e6c33
#   Stored in directory: /root/.cache/pip/wheels/e2/c3/94/1ffd5bac267cfdc2b222a4ec6915278ef18a028a916b9a5ac3
#   Building wheel for nvidia-cuda-runtime-cu11 (setup.py) ... done
#   Created wheel for nvidia-cuda-runtime-cu11: filename=nvidia_cuda_runtime_cu11-2022.4.25-py3-none-any.whl size=15696 sha256=d75690481365865674d650bce17ce4da6e0261c665c44efac06cf8013ab97782
#   Stored in directory: /root/.cache/pip/wheels/df/fe/2b/e553db7867508b2268b14ac194e9ac5b3f51f21316c282c96c
#   Building wheel for nvidia-cudnn-cu11 (setup.py) ... done
#   Created wheel for nvidia-cudnn-cu11: filename=nvidia_cudnn_cu11-2022.5.19-py3-none-any.whl size=15617 sha256=43f69114730dfc6e437c8c542cf438a2937b9a7c7ccd2c364b7111d1e1c6075e
#   Stored in directory: /root/.cache/pip/wheels/7c/32/69/9787704b5f889217708864db5e00812c8c1c349ef89084c59c
# Successfully built nvidia-cublas-cu11 nvidia-cuda-runtime-cu11 nvidia-cudnn-cu11
# Installing collected packages: nvidia-cudnn-cu116, nvidia-cuda-runtime-cu117, nvidia-cublas-cu117, nvidia-cudnn-cu11, nvidia-cuda-runtime-cu11, nvidia-cublas-cu11, nvidia-tensorrt
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/base_command.py", line 180, in _main
#     status = self.run(options, args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/req_command.py", line 199, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py", line 402, in run
#     pycompile=options.compile,
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/req/__init__.py", line 85, in install_given_reqs
#     pycompile=pycompile,
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/req/req_install.py", line 795, in install
#     requested=self.user_supplied,
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/operations/install/wheel.py", line 818, in install_wheel
#     requested=requested,
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/operations/install/wheel.py", line 653, in _install_wheel
#     file.save()
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/operations/install/wheel.py", line 420, in save
#     shutil.copyfileobj(f, dest)
#   File "/usr/lib/python3.7/shutil.py", line 79, in copyfileobj
#     buf = fsrc.read(length)
#   File "/usr/lib/python3.7/zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "/usr/lib/python3.7/zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "/usr/lib/python3.7/zipfile.py", line 1030, in _read2
#     data = self._fileobj.read(n)
#   File "/usr/lib/python3.7/zipfile.py", line 754, in read
#     data = self._file.read(n)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/main.py", line 71, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/base_command.py", line 104, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/base_command.py", line 212, in _main
#     logger.critical("Operation cancelled by user")
#   File "/usr/lib/python3.7/logging/__init__.py", line 1425, in critical
#     self._log(CRITICAL, msg, args, **kwargs)
#   File "/usr/lib/python3.7/logging/__init__.py", line 1514, in _log
#     self.handle(record)
#   File "/usr/lib/python3.7/logging/__init__.py", line 1524, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.7/logging/__init__.py", line 1586, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.7/logging/__init__.py", line 894, in handle
#     self.emit(record)
#   File "/usr/lib/python3.7/logging/__init__.py", line 1028, in emit
#     stream.write(msg + self.terminator)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "export.py", line 67, in <module>
#     from models.experimental import attempt_load
#   File "/content/yolov5/models/experimental.py", line 11, in <module>
#     from models.common import Conv
#   File "/content/yolov5/models/common.py", line 24, in <module>
#     from utils.dataloaders import exif_transpose, letterbox
#   File "/content/yolov5/utils/dataloaders.py", line 29, in <module>
#     from utils.augmentations import Albumentations, augment_hsv, copy_paste, letterbox, mixup, random_perspective
#   File "/content/yolov5/utils/augmentations.py", line 12, in <module>
#     from utils.general import LOGGER, check_version, colorstr, resample_segments, segment2box
#   File "/content/yolov5/utils/general.py", line 37, in <module>
#     from utils.metrics import box_iou, fitness
#   File "/content/yolov5/utils/metrics.py", line 10, in <module>
#     import matplotlib.pyplot as plt
#   File "/usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py", line 2282, in <module>
#     switch_backend(rcParams["backend"])
#   File "/usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py", line 221, in switch_backend
#     backend_mod = importlib.import_module(backend_name)
#   File "/usr/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/__init__.py", line 2, in <module>
#     from .connect import *
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/connect.py", line 18, in <module>
#     import jupyter_client
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 818, in get_code
#   File "<frozen importlib._bootstrap_external>", line 916, in get_data
# KeyboardInterrupt
# detect: weights=['yolov5s.engine'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-295-gf8722b4 Python-3.7.13 torch-1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# Loading yolov5s.engine for TensorRT inference...
# Traceback (most recent call last):
#   File "detect.py", line 256, in <module>
#     main(opt)
#   File "detect.py", line 251, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 92, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#   File "/content/yolov5/models/common.py", line 381, in __init__
#     import tensorrt as trt  # https://developer.nvidia.com/nvidia-tensorrt-download
# ModuleNotFoundError: No module named 'tensorrt'

# %%
# !python export.py --weights yolov5s.pt --include onnx
# Out:
# export: data=data/coco128.yaml, weights=['yolov5s.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, train=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 v6.1-295-gf8722b4 Python-3.7.13 torch-1.11.0+cu102 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
#
# PyTorch: starting from yolov5s.pt with output shape (1, 25200, 85) (14.1 MB)
# requirements: onnx not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting onnx
#   Downloading onnx-1.12.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from onnx) (1.21.6)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from onnx) (3.17.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.7/dist-packages (from onnx) (4.1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf<=3.20.1,>=3.12.2->onnx) (1.15.0)
# Installing collected packages: onnx
# Successfully installed onnx-1.12.0
#
# requirements: 1 package updated per ['onnx']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.12.0...
# ONNX: export success, saved as yolov5s.onnx (28.0 MB)
#
# Export complete (9.13s)
# Results saved to /content/yolov5
# Detect:          python detect.py --weights yolov5s.onnx
# Validate:        python val.py --weights yolov5s.onnx
# PyTorch Hub:     model = torch.hub.load('ultralytics/yolov5', 'custom', 'yolov5s.onnx')
# Visualize:       https://netron.app

# %%
# !python export.py --weights /content/yolov5/runs/train/exp/weights/best.pt --include pb
# Out:
# export: data=data/coco128.yaml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, train=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['pb']
# YOLOv5 🚀 v6.1-313-g1c5e92a Python-3.7.13 torch-1.12.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /content/yolov5/runs/train/exp/weights/best.pt with output shape (1, 25200, 6) (13.8 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.8.2...
#
#                  from  n    params  module                                  arguments
# 2022-07-23 15:51:58.557098: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512], [640, 640]]
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(1, 640, 640, 3)]   0           []
#
#  tf_conv (TFConv)               (1, 320, 320, 32)    3488        ['input_1[0][0]']
#
#  tf_conv_1 (TFConv)             (1, 160, 160, 64)    18496       ['tf_conv[0][0]']
#
#  tfc3 (TFC3)                    (1, 160, 160, 64)    18624       ['tf_conv_1[0][0]']
#
#  tf_conv_7 (TFConv)             (1, 80, 80, 128)     73856       ['tfc3[0][0]']
#
#  tfc3_1 (TFC3)                  (1, 80, 80, 128)     115200      ['tf_conv_7[0][0]']
#
#  tf_conv_15 (TFConv)            (1, 40, 40, 256)     295168      ['tfc3_1[0][0]']
#
#  tfc3_2 (TFC3)                  (1, 40, 40, 256)     623872      ['tf_conv_15[0][0]']
#
#  tf_conv_25 (TFConv)            (1, 20, 20, 512)     1180160     ['tfc3_2[0][0]']
#
#  tfc3_3 (TFC3)                  (1, 20, 20, 512)     1181184     ['tf_conv_25[0][0]']
#
#  tfsppf (TFSPPF)                (1, 20, 20, 512)     656128      ['tfc3_3[0][0]']
#
#  tf_conv_33 (TFConv)            (1, 20, 20, 256)     131328      ['tfsppf[0][0]']
#
#  tf_upsample (TFUpsample)       (1, 40, 40, 256)     0           ['tf_conv_33[0][0]']
#
#  tf_concat (TFConcat)           (1, 40, 40, 512)     0           ['tf_upsample[0][0]',
#                                                                   'tfc3_2[0][0]']
#
#  tfc3_4 (TFC3)                  (1, 40, 40, 256)     361216      ['tf_concat[0][0]']
#
#  tf_conv_39 (TFConv)            (1, 40, 40, 128)     32896       ['tfc3_4[0][0]']
#
#  tf_upsample_1 (TFUpsample)     (1, 80, 80, 128)     0           ['tf_conv_39[0][0]']
#
#  tf_concat_1 (TFConcat)         (1, 80, 80, 256)     0           ['tf_upsample_1[0][0]',
#                                                                   'tfc3_1[0][0]']
#
#  tfc3_5 (TFC3)                  (1, 80, 80, 128)     90496       ['tf_concat_1[0][0]']
#
#  tf_conv_45 (TFConv)            (1, 40, 40, 128)     147584      ['tfc3_5[0][0]']
#
#  tf_concat_2 (TFConcat)         (1, 40, 40, 256)     0           ['tf_conv_45[0][0]',
#                                                                   'tf_conv_39[0][0]']
#
#  tfc3_6 (TFC3)                  (1, 40, 40, 256)     295680      ['tf_concat_2[0][0]']
#
#  tf_conv_51 (TFConv)            (1, 20, 20, 256)     590080      ['tfc3_6[0][0]']
#
#  tf_concat_3 (TFConcat)         (1, 20, 20, 512)     0           ['tf_conv_51[0][0]',
#                                                                   'tf_conv_33[0][0]']
#
#  tfc3_7 (TFC3)                  (1, 20, 20, 512)     1181184     ['tf_concat_3[0][0]']
#
#  tf_detect (TFDetect)           ((1, 25200, 6),      16182       ['tfc3_5[0][0]',
#                                  [(1, 6400, 3, 6),                'tfc3_6[0][0]',
#                                  (1, 1600, 3, 6),                 'tfc3_7[0][0]']
#                                  (1, 400, 3, 6)])
#
# ==================================================================================================
# Total params: 7,012,822
# Trainable params: 0
# Non-trainable params: 7,012,822
# __________________________________________________________________________________________________
# 2022-07-23 15:52:07.074646: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# Assets written to: /content/yolov5/runs/train/exp/weights/best_saved_model/assets
# TensorFlow SavedModel: export success, saved as /content/yolov5/runs/train/exp/weights/best_saved_model (27.0 MB)
#
# TensorFlow GraphDef: starting export with tensorflow 2.8.2...
# TensorFlow GraphDef: export success, saved as /content/yolov5/runs/train/exp/weights/best.pb (27.0 MB)
#
# Export complete (16.45s)
# Results saved to /content/yolov5/runs/train/exp/weights
# Detect:          python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pb
# Validate:        python val.py --weights /content/yolov5/runs/train/exp/weights/best.pb
# PyTorch Hub:     model = torch.hub.load('ultralytics/yolov5', 'custom', '/content/yolov5/runs/train/exp/weights/best.pb')
# Visualize:       https://netron.app
